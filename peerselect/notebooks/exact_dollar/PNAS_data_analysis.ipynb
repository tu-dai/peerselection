# %% [markdown]
# File to Open the pickled results from the pnas_longruns.py script and make sure we can do analysis etc. on them.
#
# The initial run had the following parameters:
#
# $s = 100$
#
# $n = 130$
#
# $k \in 15, 20, 25, 30, 35$
#
# $m \in 5, 7, 9, 11, 13, 15$
#
# $l \in 3, 4, 5, 6$
#
# $\phi \in 0.0, 0.1, 0.2, 0.35, 0.5$
#
# As confirmed in the other notebook, there is no change varying phi.  It doesn't seem to make a difference.  We set it to 0.5 so we get a bit of noise but it doesn't really matter unless we are judging against the underlying ordering.  Then we don't get a dropoff till we get very close to 1.0
#
# Everyone does worse as we sweep l.  We maintain an advantage of about 3-5% increase on average, a 10-20% decrease in standerded deviation, and in the worst case, select 0-2 more people in the vanilla set.

# %%
import sys
sys.path.insert(0, "/home/szhydkov/Documents/mattei peer review/extedned_peer_selection/peerselect")

# %%
### Standard Magic and startup initializers.

import math
import csv
import numpy as np
import random
import itertools
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

_DEBUG = False

from peerselect import impartial
from peerselect import profile_generator

# %matplotlib inline
matplotlib.style.use('seaborn-whitegrid')

font = {'size'   : 22}

matplotlib.rc('font', **font)

### Load Datafiles..
## Load some stuff from Pickle..
import pickle

## Open an older file
with open("../db/final_v3.pkl", 'rb') as input_file:
     results = pickle.load(input_file)
        
## Open an older file
with open("../db/final3.pkl", 'rb') as input_file:
     base_results = pickle.load(input_file)

# Print the keys.
print("n, k, m, l, p, s")
for k,v in results.items():
    print(k)
# Out:
# n, k, m, l, p, s
# (120, 15, 5, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 5, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 5, 4, 0.5, 1000, 'Partition')
# (120, 15, 5, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 5, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 5, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 5, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 6, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 6, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 6, 4, 0.5, 1000, 'Partition')
# (120, 15, 6, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 6, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 6, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 6, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 7, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 7, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 7, 4, 0.5, 1000, 'Partition')
# (120, 15, 7, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 7, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 7, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 7, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 8, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 8, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 8, 4, 0.5, 1000, 'Partition')
# (120, 15, 8, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 8, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 8, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 8, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 9, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 9, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 9, 4, 0.5, 1000, 'Partition')
# (120, 15, 9, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 9, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 9, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 9, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 10, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 10, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 10, 4, 0.5, 1000, 'Partition')
# (120, 15, 10, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 10, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 10, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 10, 4, 0.5, 1000, 'PeerNomination')
# (120, 15, 11, 4, 0.5, 1000, 'Vanilla')
# (120, 15, 11, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 15, 11, 4, 0.5, 1000, 'Partition')
# (120, 15, 11, 4, 0.5, 1000, 'DollarRaffle')
# (120, 15, 11, 4, 0.5, 1000, 'CredibleSubset')
# (120, 15, 11, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 15, 11, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 5, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 5, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 5, 4, 0.5, 1000, 'Partition')
# (120, 20, 5, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 5, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 5, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 5, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 6, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 6, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 6, 4, 0.5, 1000, 'Partition')
# (120, 20, 6, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 6, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 6, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 6, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 7, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 7, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 7, 4, 0.5, 1000, 'Partition')
# (120, 20, 7, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 7, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 7, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 7, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 8, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 8, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 8, 4, 0.5, 1000, 'Partition')
# (120, 20, 8, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 8, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 8, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 8, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 9, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 9, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 9, 4, 0.5, 1000, 'Partition')
# (120, 20, 9, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 9, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 9, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 9, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 10, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 10, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 10, 4, 0.5, 1000, 'Partition')
# (120, 20, 10, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 10, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 10, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 10, 4, 0.5, 1000, 'PeerNomination')
# (120, 20, 11, 4, 0.5, 1000, 'Vanilla')
# (120, 20, 11, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 20, 11, 4, 0.5, 1000, 'Partition')
# (120, 20, 11, 4, 0.5, 1000, 'DollarRaffle')
# (120, 20, 11, 4, 0.5, 1000, 'CredibleSubset')
# (120, 20, 11, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 20, 11, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 5, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 5, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 5, 4, 0.5, 1000, 'Partition')
# (120, 25, 5, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 5, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 5, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 5, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 6, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 6, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 6, 4, 0.5, 1000, 'Partition')
# (120, 25, 6, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 6, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 6, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 6, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 7, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 7, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 7, 4, 0.5, 1000, 'Partition')
# (120, 25, 7, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 7, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 7, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 7, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 8, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 8, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 8, 4, 0.5, 1000, 'Partition')
# (120, 25, 8, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 8, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 8, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 8, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 9, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 9, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 9, 4, 0.5, 1000, 'Partition')
# (120, 25, 9, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 9, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 9, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 9, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 10, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 10, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 10, 4, 0.5, 1000, 'Partition')
# (120, 25, 10, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 10, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 10, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 10, 4, 0.5, 1000, 'PeerNomination')
# (120, 25, 11, 4, 0.5, 1000, 'Vanilla')
# (120, 25, 11, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 25, 11, 4, 0.5, 1000, 'Partition')
# (120, 25, 11, 4, 0.5, 1000, 'DollarRaffle')
# (120, 25, 11, 4, 0.5, 1000, 'CredibleSubset')
# (120, 25, 11, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 25, 11, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 5, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 5, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 5, 4, 0.5, 1000, 'Partition')
# (120, 30, 5, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 5, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 5, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 5, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 6, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 6, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 6, 4, 0.5, 1000, 'Partition')
# (120, 30, 6, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 6, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 6, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 6, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 7, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 7, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 7, 4, 0.5, 1000, 'Partition')
# (120, 30, 7, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 7, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 7, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 7, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 8, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 8, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 8, 4, 0.5, 1000, 'Partition')
# (120, 30, 8, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 8, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 8, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 8, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 9, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 9, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 9, 4, 0.5, 1000, 'Partition')
# (120, 30, 9, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 9, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 9, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 9, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 10, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 10, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 10, 4, 0.5, 1000, 'Partition')
# (120, 30, 10, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 10, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 10, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 10, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 11, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 11, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 11, 4, 0.5, 1000, 'Partition')
# (120, 30, 11, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 11, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 11, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 11, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 5, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 5, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 5, 4, 0.5, 1000, 'Partition')
# (120, 35, 5, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 5, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 5, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 5, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 6, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 6, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 6, 4, 0.5, 1000, 'Partition')
# (120, 35, 6, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 6, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 6, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 6, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 7, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 7, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 7, 4, 0.5, 1000, 'Partition')
# (120, 35, 7, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 7, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 7, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 7, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 8, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 8, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 8, 4, 0.5, 1000, 'Partition')
# (120, 35, 8, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 8, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 8, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 8, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 9, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 9, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 9, 4, 0.5, 1000, 'Partition')
# (120, 35, 9, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 9, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 9, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 9, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 10, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 10, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 10, 4, 0.5, 1000, 'Partition')
# (120, 35, 10, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 10, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 10, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 10, 4, 0.5, 1000, 'PeerNomination')
# (120, 35, 11, 4, 0.5, 1000, 'Vanilla')
# (120, 35, 11, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 35, 11, 4, 0.5, 1000, 'Partition')
# (120, 35, 11, 4, 0.5, 1000, 'DollarRaffle')
# (120, 35, 11, 4, 0.5, 1000, 'CredibleSubset')
# (120, 35, 11, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 35, 11, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 13, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 13, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 13, 4, 0.5, 1000, 'Partition')
# (120, 30, 13, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 13, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 13, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 13, 4, 0.5, 1000, 'PeerNomination')
# (120, 30, 15, 4, 0.5, 1000, 'Vanilla')
# (120, 30, 15, 4, 0.5, 1000, 'ExactDollarPartition')
# (120, 30, 15, 4, 0.5, 1000, 'Partition')
# (120, 30, 15, 4, 0.5, 1000, 'DollarRaffle')
# (120, 30, 15, 4, 0.5, 1000, 'CredibleSubset')
# (120, 30, 15, 4, 0.5, 1000, 'DollarPartitionRaffle')
# (120, 30, 15, 4, 0.5, 1000, 'PeerNomination')

# %%
#
# Takes a slice of the array and generates the graphs etc.
#
def make_output(df, test, labels):
    means = df.loc[:, test].mean().unstack()
    errors = df.loc[:, test].std().unstack()
    mins = df.loc[:, test].min().unstack()
    print(means)
    print(errors)

    print("\t\tApproximate Vanilla Ordering")
    means = means[['Vanilla', "PeerNomination", 'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'DollarRaffle', 'CredibleSubset']]
    errors = errors[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'DollarRaffle', 'CredibleSubset']]
    
    means['PercentChange'] = (means.ExactDollarPartition - means.Partition) / means.Partition * 100.
    errors['PercentChange'] = (errors.ExactDollarPartition - errors.Partition) / errors.Partition * 100.
    mins['PercentChange'] = (mins.ExactDollarPartition - mins.Partition) / mins.Partition * 100.
    print("\t\t MEAN:\n" + str(means[['Vanilla','ExactDollarPartition', 'Partition', 'PercentChange']]))
    print("\t\t STD:\n" + str(errors[['Vanilla','ExactDollarPartition', 'Partition', 'PercentChange']]))
    print("\t\t MIN:\n" + str(mins[['Vanilla','ExactDollarPartition', 'Partition', 'PercentChange']]))
    del means['PercentChange']
    del errors['PercentChange']
    del mins['PercentChange']
    
    for index, row in means.iterrows():
        means.ix[index] = row / float(index[1])
    for index, row in errors.iterrows():
        errors.ix[index] = row / float(index[1])
    
    print(errors)
    
    #Set colors..
    color_list = plt.cm.Paired(np.linspace(0, 1, 6))
    color_list = color_list[:6]
    #color_list = sns.color_palette("pastel", 6)
    means.plot(kind='bar', legend=False, yerr=errors.values.T, figsize=(20, 10), ylim=(0.0, 1.05), \
            color=color_list, error_kw={'ecolor':'Black', 'linewidth':2, 'capsize':4}, width=0.75)
    plt.title("Strict Preference, Borda Scoring, Versus Vanilla Ordering")
    plt.legend(bbox_to_anchor = (0,0.01,1,1), bbox_transform=plt.gcf().transFigure, loc='upper center', ncol=6, borderaxespad=0.)
    plt.gca().set_xticklabels(labels)
    plt.gca().set_xlabel("")
    plt.show()
    
v_df = pd.DataFrame(results)
v_df.columns.names = ['n', 'k', 'm', 'l', 'p', 's', 'algo']

gt_df = pd.DataFrame(base_results)
gt_df.columns.names = ['n', 'k', 'm', 'l', 'p', 's', 'algo']

# %%
#  Vary the number of Selected
#  ['n', 'k', 'm', 'l', 'p', 's', 'algo']
# make_output(v_df, (130, 30, slice(None), 4, 0.5, 1000), v_df.columns.levels[2])
# make_output(v_df, (130, 30, slice(None), 4, 0.5, 1000), v_df.columns.levels[2])

make_output(gt_df, (120, 30, slice(None), 4, 0.5, 100), gt_df.columns.levels[1])
# Out:
# algo                 CredibleSubset  DollarPartitionRaffle  DollarRaffle  \
# n   k  m  l p   s
# 120 30 5  4 0.5 100           21.44                  23.15         10.67
#        6  4 0.5 100           20.80                  23.37         10.99
#        7  4 0.5 100           23.28                  24.00         11.43
#        8  4 0.5 100           19.34                  24.55         11.30
#        9  4 0.5 100           20.99                  23.94         11.27
#        10 4 0.5 100           19.50                  24.56         11.61
#        11 4 0.5 100           19.29                  24.58         11.96
#
# algo                 ExactDollarPartition  Partition  PeerNomination  Vanilla
# n   k  m  l p   s
# 120 30 5  4 0.5 100                 24.46      24.36           24.08    25.43
#        6  4 0.5 100                 24.68      24.34           24.51    25.32
#        7  4 0.5 100                 25.47      25.20           26.01    26.43
#        8  4 0.5 100                 25.61      25.22           26.45    26.82
#        9  4 0.5 100                 25.07      24.71           26.01    26.25
#        10 4 0.5 100                 26.03      25.59           26.53    27.08
#        11 4 0.5 100                 26.06      25.75           26.91    27.17
# algo                 CredibleSubset  DollarPartitionRaffle  DollarRaffle  \
# n   k  m  l p   s
# 120 30 5  4 0.5 100        9.481849               1.827815      2.243081
#        6  4 0.5 100        9.884178               1.618423      2.002498
#        7  4 0.5 100        8.728312               1.989873      1.986088
#        8  4 0.5 100       12.164877               1.659834      2.148525
#        9  4 0.5 100       10.599690               1.895343      2.251173
#        10 4 0.5 100       12.259402               2.075932      2.024571
#        11 4 0.5 100       12.426995               1.923696      1.927578
#
# algo                 ExactDollarPartition  Partition  PeerNomination   Vanilla
# n   k  m  l p   s
# 120 30 5  4 0.5 100              1.533597   1.592406        1.878534  1.327677
#        6  4 0.5 100              1.377159   1.342544        1.817396  1.420485
#        7  4 0.5 100              1.336776   1.310409        1.396207  1.304654
#        8  4 0.5 100              1.136137   1.404035        1.233988  1.158020
#        9  4 0.5 100              1.327677   1.472269        1.579509  1.122542
#        10 4 0.5 100              1.290642   1.334053        1.466494  1.151898
#        11 4 0.5 100              1.331969   1.305582        1.356578  1.128644
# 		Approximate Vanilla Ordering
# 		 MEAN:
# algo                 Vanilla  ExactDollarPartition  Partition  PercentChange
# n   k  m  l p   s
# 120 30 5  4 0.5 100    25.43                 24.46      24.36       0.410509
#        6  4 0.5 100    25.32                 24.68      24.34       1.396878
#        7  4 0.5 100    26.43                 25.47      25.20       1.071429
#        8  4 0.5 100    26.82                 25.61      25.22       1.546392
#        9  4 0.5 100    26.25                 25.07      24.71       1.456900
#        10 4 0.5 100    27.08                 26.03      25.59       1.719422
#        11 4 0.5 100    27.17                 26.06      25.75       1.203883
# 		 STD:
# algo                  Vanilla  ExactDollarPartition  Partition  PercentChange
# n   k  m  l p   s
# 120 30 5  4 0.5 100  1.327677              1.533597   1.592406      -3.693116
#        6  4 0.5 100  1.420485              1.377159   1.342544       2.578284
#        7  4 0.5 100  1.304654              1.336776   1.310409       2.012110
#        8  4 0.5 100  1.158020              1.136137   1.404035     -19.080530
#        9  4 0.5 100  1.122542              1.327677   1.472269      -9.820999
#        10 4 0.5 100  1.151898              1.290642   1.334053      -3.254033
#        11 4 0.5 100  1.128644              1.331969   1.305582       2.021058
# 		 MIN:
# algo                 Vanilla  ExactDollarPartition  Partition  PercentChange
# n   k  m  l p   s
# 120 30 5  4 0.5 100       21                    21         20       5.000000
#        6  4 0.5 100       22                    21         21       0.000000
#        7  4 0.5 100       23                    22         21       4.761905
#        8  4 0.5 100       23                    23         22       4.545455
#        9  4 0.5 100       23                    22         20      10.000000
#        10 4 0.5 100       24                    22         23      -4.347826
#        11 4 0.5 100       25                    23         21       9.523810
# algo                  Vanilla  PeerNomination  ExactDollarPartition  \
# n   k  m  l p   s
# 120 30 5  4 0.5 100  0.044256        0.062618              0.051120
#        6  4 0.5 100  0.047350        0.060580              0.045905
#        7  4 0.5 100  0.043488        0.046540              0.044559
#        8  4 0.5 100  0.038601        0.041133              0.037871
#        9  4 0.5 100  0.037418        0.052650              0.044256
#        10 4 0.5 100  0.038397        0.048883              0.043021
#        11 4 0.5 100  0.037621        0.045219              0.044399
#
# algo                 Partition  DollarPartitionRaffle  DollarRaffle  \
# n   k  m  l p   s
# 120 30 5  4 0.5 100   0.053080               0.060927      0.074769
#        6  4 0.5 100   0.044751               0.053947      0.066750
#        7  4 0.5 100   0.043680               0.066329      0.066203
#        8  4 0.5 100   0.046801               0.055328      0.071618
#        9  4 0.5 100   0.049076               0.063178      0.075039
#        10 4 0.5 100   0.044468               0.069198      0.067486
#        11 4 0.5 100   0.043519               0.064123      0.064253
#
# algo                 CredibleSubset
# n   k  m  l p   s
# 120 30 5  4 0.5 100        0.316062
#        6  4 0.5 100        0.329473
#        7  4 0.5 100        0.290944
#        8  4 0.5 100        0.405496
#        9  4 0.5 100        0.353323
#        10 4 0.5 100        0.408647
#        11 4 0.5 100        0.414233
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
### Publication Graphic... 2x2
#
#  k=25: v_df v. m, b_df v. m
#  k=35: v_df v. m, b_df v. m

t = (120, slice(None), 9, 4, 0.5, 1000)
t2 = (120, 30, slice(None), 4, 0.5, 1000)
# print(t2)
# print(v_df.loc[:, t2])

v_1m = v_df.loc[:, t].mean().unstack()
gt_1m = gt_df.loc[:, t].mean().unstack()
v_1e = v_df.loc[:, t].std().unstack()
gt_1e = gt_df.loc[:, t].std().unstack()

v_2m = v_df.loc[:, t2].mean().unstack()
gt_2m = gt_df.loc[:, t2].mean().unstack()
v_2e = v_df.loc[:, t2].std().unstack()
gt_2e = gt_df.loc[:, t2].std().unstack()

v_1m = v_1m[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
gt_1m = gt_1m[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
v_1e = v_1e[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
gt_1e = gt_1e[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]

v_2m = v_2m[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
gt_2m = gt_2m[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
v_2e = v_2e[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]
gt_2e = gt_2e[['Vanilla',"PeerNomination" ,'ExactDollarPartition', 'Partition', 'DollarPartitionRaffle', 'CredibleSubset']]

#Normalize
for index, row in v_1m.iterrows():
    v_1m.ix[index] = v_1m.ix[index] / float(index[1])
    v_1e.ix[index] = v_1e.ix[index] / float(index[1])
    gt_1m.ix[index] = gt_1m.ix[index] / float(index[1])
    gt_1e.ix[index] = gt_1e.ix[index] / float(index[1])

for index, row in v_2m.iterrows():
    v_2m.ix[index] = v_2m.ix[index] / float(index[1])
    v_2e.ix[index] = v_2e.ix[index] / float(index[1])
    gt_2m.ix[index] = gt_2m.ix[index] / float(index[1])
    gt_2e.ix[index] = gt_2e.ix[index] / float(index[1])
    

v_2m = v_2m.loc[(120, 30, slice(5,17,2), 4, 0.5, 1000), :]
gt_2m = gt_2m.loc[(120, 30, slice(5,17,2), 4, 0.5, 1000), :]
v_2e = v_2e.loc[(120, 30, slice(5,17,2), 4, 0.5, 1000), :]
gt_2e = gt_2e.loc[(120, 30, slice(5,17,2), 4, 0.5, 1000), :]
    
fig, axarr = plt.subplots(nrows=2, ncols=2, sharey=True)
fig.set_size_inches(25,10)
# fig.tight_layout()
 
#Set colors..
color_list = plt.cm.Paired(np.linspace(0, 1, 6))
color_list = color_list[:6]

w = 0.85

v_1m.plot(ax=axarr[0,0], kind='bar', legend=False, yerr=v_1e.values.T, ylim=(0.0, 1.05), \
            color=color_list, error_kw={'ecolor':'Black', 'linewidth':2, 'capsize':4}, width=w)

v_2m.plot(ax=axarr[1,0], kind='bar', legend=False, yerr=v_2e.values.T, ylim=(0.0, 1.05), \
            color=color_list, error_kw={'ecolor':'Black', 'linewidth':2, 'capsize':4}, width=w)


gt_1m.plot(ax=axarr[0,1], kind='bar', legend=False, yerr=gt_1e.values.T, ylim=(0.0, 1.05), \
            color=color_list, error_kw={'ecolor':'Black', 'linewidth':2, 'capsize':4}, width=w)

gt_2m.plot(ax=axarr[1,1], kind='bar', legend=False, yerr=gt_2e.values.T, ylim=(0.0, 1.05), \
            color=color_list, error_kw={'ecolor':'Black', 'linewidth':2, 'capsize':4}, width=w)

#plt.title("Strict Preference, Borda Scoring, Versus Vanilla Ordering")
plt.legend(bbox_to_anchor = (0,-0.05,1,1), bbox_transform=plt.gcf().transFigure, loc='lower center', ncol=6, borderaxespad=0.)
plt.yticks(np.arange(0.5,1.01,0.1))
plt.ylim([0.5,1])
axarr[0,0].set_title("Versus Vanilla")
axarr[0,0].set_xticklabels(v_df.columns.levels[1])
axarr[0,0].set_xlabel("$k$")

axarr[1, 0].set_xticklabels(range(5,17,2))
axarr[1, 0].set_xlabel("$m$")

axarr[0,1].set_title("Versus Ground Truth")
axarr[0,1].set_xticklabels(v_df.columns.levels[1])
axarr[0,1].set_xlabel("$k$")

axarr[1, 1].set_xticklabels(range(5,17,2))
axarr[1, 1].set_xlabel("$m$")

# plt.tight_layout()
# plt.savefig("test_final.pdf",bbox_inches='tight')
plt.show()
# Out:
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:33: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/szhydkov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
np.arange(0.5,1.01,0.1)
# Out:
# array([0.5, 0.6, 0.7, 0.8, 0.9, 1. ])

# %%
gt_2m.loc[(120, 30, slice(5,13,2), 4, 0.5, 1000), :]
# Out:
# algo                   Vanilla  PeerNomination  ExactDollarPartition  \
# n   k  m  l p   s
# 120 30 5  4 0.5 1000  0.854433        0.798233              0.819100
#        7  4 0.5 1000  0.877400        0.856133              0.843600
#        9  4 0.5 1000  0.870967        0.866800              0.840067
#        11 4 0.5 1000  0.906267        0.901000              0.868000
#
# algo                  Partition  DollarPartitionRaffle  CredibleSubset
# n   k  m  l p   s
# 120 30 5  4 0.5 1000   0.813633               0.783067        0.724333
#        7  4 0.5 1000   0.833167               0.800667        0.715233
#        9  4 0.5 1000   0.829500               0.800000        0.679033
#        11 4 0.5 1000   0.852567               0.820700        0.671667

# %%
v_df.loc[(120, 30, 5, 4, 0.5, 1000):(120, 30, 7, 4, 0.5, 1000)]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-100-3bf515317ebc> in <module>()
# ----> 1 v_df.loc[(120, 30, 5, 4, 0.5, 1000):(120, 30, 7, 4, 0.5, 1000)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1864         if isinstance(key, slice):
#    1865             self._validate_key(key, axis)
# -> 1866             return self._get_slice_axis(key, axis=axis)
#    1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1509         labels = obj._get_axis(axis)
#    1510         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1511                                        slice_obj.step, kind=self.name)
#    1512
#    1513         if isinstance(indexer, slice):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4092         # return a slice
#    4093         if not is_scalar(start_slice):
# -> 4094             raise AssertionError("Start slice bound is non-scalar")
#    4095         if not is_scalar(end_slice):
#    4096             raise AssertionError("End slice bound is non-scalar")
#
# AssertionError: Start slice bound is non-scalar

# %%
t2 = [(120, 30, m, 4, 0.5, 1000) for m in range(5,13,2)]

# %%
t2
# Out:
# [(120, 30, 5, 4, 0.5, 1000),
#  (120, 30, 7, 4, 0.5, 1000),
#  (120, 30, 9, 4, 0.5, 1000),
#  (120, 30, 11, 4, 0.5, 1000)]
